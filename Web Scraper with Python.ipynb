# %%
import urllib.request
from bs4 import BeautifulSoup


class Scraper:
    def __init__(self, site):
        self.site = site

# %%
def scrape(self):
        r = urllib.request.urlopen(self.site)
        html = r.read()

# %%
 def scrape(self):
        r = urllib.request.urlopen(self.site)
        html = r.read()
        parser = "html.parser"
        sp = BeautifulSoup(html,parser)

# %%
 def scrape(self):
        r = urllib.request.urlopen(self.site)
        html = r.read()
        parser = "html.parser"
        sp = BeautifulSoup(html,parser)
        for tag in sp.find_all("a"):
            url = tag.get("href")
            if url is None:
                continue
            if "articles" in url:
                print("\n" + url)

# %%
import urllib.request
from bs4 import BeautifulSoup


class Scraper:
    def __init__(self, site):
        self.site = site

    def scrape(self):
        r = urllib.request.urlopen(self.site)
        html = r.read()
        parser = "html.parser"
        sp = BeautifulSoup(html,parser)
        for tag in sp.find_all("a"):
            url = tag.get("href")
            if url is None:
                continue
            if "articles" in url:
                print("\n" + url)

news = "https://news.google.com/"
Scraper(news).scrape()
# Out:
# ./articles/CAIiEINzt2gMQftvSOcjOw5nYWgqGQgEKhAIACoHCAowj8n_CjDIrfkCMJWZ2AY?hl=en-IN&gl=IN&ceid=IN%3Aen
#
# ./articles/CAIiEINzt2gMQftvSOcjOw5nYWgqGQgEKhAIACoHCAowj8n_CjDIrfkCMJWZ2AY?hl=en-IN&gl=IN&ceid=IN%3Aen
#
# ./articles/CAIiEINzt2gMQftvSOcjOw5nYWgqGQgEKhAIACoHCAowj8n_CjDIrfkCMJWZ2AY?hl=en-IN&gl=IN&ceid=IN%3Aen
#
# ./articles/CAIiEL3V0vGhQMHZa2JYMHR_Og8qFwgEKg4IACoGCAowxLQ_MNevCDDnvNMF?hl=en-IN&gl=IN&ceid=IN%3Aen
#
# ./articles/CAIiEL3V0vGhQMHZa2JYMHR_Og8qFwgEKg4IACoGCAowxLQ_MNevCDDnvNMF?hl=en-IN&gl=IN&ceid=IN%3Aen
#
# ./articles/CAIiEIuQmfsdZcaCSbkiZSR84YIqGQgEKhAIACoHCAowzrL9CjDC7vQCMJmD1wU?hl=en-IN&gl=IN&ceid=IN%3Aen
#
# ./articles/CAIiEIuQmfsdZcaCSbkiZSR84YIqGQgEKhAIACoHCAowzrL9CjDC7vQCMJmD1wU?hl=en-IN&gl=IN&ceid=IN%3Aen
#
# ./articles/CAIiEGpUEEt133wBgvcZfv8nAmQqGQgEKhAIACoHCAowlbCPCzCrzaIDMLL1zQY?hl=en-IN&gl=IN&ceid=IN%3Aen
#
# ./articles/CAIiEGpUEEt133wBgvcZfv8nAmQqGQgEKhAIACoHCAowlbCPCzCrzaIDMLL1zQY?hl=en-IN&gl=IN&ceid=IN%3Aen
#
# ./articles/CAIiELN5t2DVL8lowa2GE9Gz6bYqFwgEKg4IACoGCAowxLQ_MNevCDDnvNMF?hl=en-IN&gl=IN&ceid=IN%3Aen
#
# ./articles/CAIiELN5t2DVL8lowa2GE9Gz6bYqFwgEKg4IACoGCAowxLQ_MNevCDDnvNMF?hl=en-IN&gl=IN&ceid=IN%3Aen
#
# ./articles/CAIiEOBIR16KgAG1C_5KTuxPFTkqGQgEKhAIACoHCAow5qqNCzD4q58DMPbXpwY?hl=en-IN&gl=IN&ceid=IN%3Aen
#
# ./articles/CAIiEOBIR16KgAG1C_5KTuxPFTkqGQgEKhAIACoHCAow5qqNCzD4q58DMPbXpwY?hl=en-IN&gl=IN&ceid=IN%3Aen
#
# ./articles/CAIiEOBIR16KgAG1C_5KTuxPFTkqGQgEKhAIACoHCAow5qqNCzD4q58DMPbXpwY?hl=en-IN&gl=IN&ceid=IN%3Aen
#
# ./articles/CAIiENSjyPaiwVNSPc3VODZ6sJgqGQgEKhAIACoHCAowzrL9CjDC7vQCMOXc1gU?hl=en-IN&gl=IN&ceid=IN%3Aen
#
# ./articles/CAIiENSjyPaiwVNSPc3VODZ6sJgqGQgEKhAIACoHCAowzrL9CjDC7vQCMOXc1gU?hl=en-IN&gl=IN&ceid=IN%3Aen
#
# ./articles/CAIiENSjyPaiwVNSPc3VODZ6sJgqGQgEKhAIACoHCAowzrL9CjDC7vQCMOXc1gU?hl=en-IN&gl=IN&ceid=IN%3Aen
#
# ./articles/CAIiEHtCqvMgXJQtfvVNRW8zpmkqGQgEKhAIACoHCAowj8n_CjDIrfkCMNCf6AU?hl=en-IN&gl=IN&ceid=IN%3Aen
#
# ./articles/CAIi